# %% [markdown]
# # Searching & Sorting
#
# > Foundational but still commonly asked.
#
# ---
#
# ## Key Concepts
#
# - Binary Search Variants
# - Heap / Priority Queue
# - Divide and Conquer
#
# ---

# %% [markdown]
# ## Q1. Binary Search
#
# **Difficulty:** Easy
#
# **Problem:**
# Given an array of integers `nums` sorted in ascending order and an integer `target`, return the index of `target`. If not found, return `-1`. Must run in O(log n).
#
# **Example:**
# ```
# Input:  nums = [-1,0,3,5,9,12], target = 9
# Output: 4
# ```
#
# **Concepts:** Binary Search

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q2. Search in Rotated Sorted Array
#
# **Difficulty:** Medium
#
# **Problem:**
# Given a rotated sorted array `nums` (no duplicates) and a `target`, return the index of `target` or `-1` if not found. Must run in O(log n).
#
# **Example:**
# ```
# Input:  nums = [4,5,6,7,0,1,2], target = 0
# Output: 4
# ```
#
# **Concepts:** Binary Search Variants

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q3. Find Peak Element
#
# **Difficulty:** Medium
#
# **Problem:**
# A peak element is one that is strictly greater than its neighbors. Given an integer array `nums`, return the index of any peak element. Must run in O(log n).
#
# **Example:**
# ```
# Input:  nums = [1, 2, 3, 1]
# Output: 2  (nums[2] = 3 is a peak)
# ```
#
# **Concepts:** Binary Search Variants

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q4. Kth Largest Element in Array
#
# **Difficulty:** Medium
#
# **Problem:**
# Given an integer array `nums` and an integer `k`, return the `k`th largest element. Note: it's the `k`th largest in sorted order, not the `k`th distinct.
#
# **Example:**
# ```
# Input:  nums = [3,2,1,5,6,4], k = 2
# Output: 5
# ```
#
# **Concepts:** Heap, QuickSelect

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q5. Merge Sort
#
# **Difficulty:** Medium
#
# **Problem:**
# Implement the Merge Sort algorithm to sort an array of integers in ascending order.
#
# **Example:**
# ```
# Input:  nums = [38, 27, 43, 3, 9, 82, 10]
# Output: [3, 9, 10, 27, 38, 43, 82]
# ```
#
# **Concepts:** Divide and Conquer, Recursion

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q6. Quick Sort
#
# **Difficulty:** Medium
#
# **Problem:**
# Implement the Quick Sort algorithm to sort an array of integers in ascending order.
#
# **Example:**
# ```
# Input:  nums = [10, 7, 8, 9, 1, 5]
# Output: [1, 5, 7, 8, 9, 10]
# ```
#
# **Concepts:** Divide and Conquer, Partitioning, Recursion

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q7. Top K Frequent Elements
#
# **Difficulty:** Medium
#
# **Problem:**
# Given an integer array `nums` and an integer `k`, return the `k` most frequent elements. The answer may be returned in any order.
#
# **Example:**
# ```
# Input:  nums = [1,1,1,2,2,3], k = 2
# Output: [1, 2]
# ```
#
# **Concepts:** Heap, Bucket Sort, Hashing

# %%
# Write your solution here
