# %% [markdown]
# # Linked Lists
#
# > Interviewers test pointer manipulation and edge cases.
#
# ---
#
# ## Key Concepts
#
# - Fast & Slow Pointers
# - Dummy Nodes
# - Recursion vs Iteration
# - In-place modification
#
# ---

# %% [markdown]
# ## Q1. Reverse a Linked List
#
# **Difficulty:** Easy
#
# **Problem:**
# Given the head of a singly linked list, reverse the list and return the reversed list.
#
# **Example:**
# ```
# Input:  head = [1, 2, 3, 4, 5]
# Output: [5, 4, 3, 2, 1]
# ```
#
# **Concepts:** Iteration, Recursion, In-place modification

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q2. Detect Cycle in Linked List
#
# **Difficulty:** Medium
#
# **Problem:**
# Given the head of a linked list, determine if the linked list has a cycle in it. Return `true` if there is a cycle, otherwise `false`.
#
# **Example:**
# ```
# Input:  head = [3, 2, 0, -4], pos = 1  (tail connects to node at index 1)
# Output: true
# ```
#
# **Concepts:** Fast & Slow Pointers (Floyd's Cycle Detection)

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q3. Merge Two Sorted Lists
#
# **Difficulty:** Easy
#
# **Problem:**
# Given the heads of two sorted linked lists, merge them into one sorted linked list and return its head.
#
# **Example:**
# ```
# Input:  list1 = [1, 2, 4], list2 = [1, 3, 4]
# Output: [1, 1, 2, 3, 4, 4]
# ```
#
# **Concepts:** Dummy Nodes, Recursion vs Iteration

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q4. Remove Nth Node From End
#
# **Difficulty:** Medium
#
# **Problem:**
# Given the head of a linked list, remove the `n`th node from the end of the list and return its head.
#
# **Example:**
# ```
# Input:  head = [1, 2, 3, 4, 5], n = 2
# Output: [1, 2, 3, 5]
# ```
#
# **Concepts:** Fast & Slow Pointers, Dummy Nodes

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q5. Intersection of Two Linked Lists
#
# **Difficulty:** Easy
#
# **Problem:**
# Given the heads of two singly linked lists, return the node at which the two lists intersect. If the two linked lists have no intersection, return `null`.
#
# **Example:**
# ```
# Input:  listA = [4,1,8,4,5], listB = [5,6,1,8,4,5]  (intersect at node with value 8)
# Output: node with value 8
# ```
#
# **Concepts:** Two Pointers

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q6. Palindrome Linked List
#
# **Difficulty:** Easy
#
# **Problem:**
# Given the head of a singly linked list, return `true` if it is a palindrome, or `false` otherwise. Solve in O(n) time and O(1) space.
#
# **Example:**
# ```
# Input:  head = [1, 2, 2, 1]
# Output: true
# ```
#
# **Concepts:** Fast & Slow Pointers, Reverse Linked List

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q7. Reorder List
#
# **Difficulty:** Medium
#
# **Problem:**
# Given the head of a singly linked list `L0 → L1 → ... → Ln`, reorder it to: `L0 → Ln → L1 → Ln-1 → L2 → Ln-2 → ...`. Do it in-place.
#
# **Example:**
# ```
# Input:  head = [1, 2, 3, 4, 5]
# Output: [1, 5, 2, 4, 3]
# ```
#
# **Concepts:** Fast & Slow Pointers, Reverse Linked List, Merge

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q8. Copy List with Random Pointer
#
# **Difficulty:** Medium
#
# **Problem:**
# A linked list of length `n` has each node with an extra `random` pointer that could point to any node in the list or `null`. Construct a deep copy of the list.
#
# **Example:**
# ```
# Input:  head = [[7,null],[13,0],[11,4],[10,2],[1,0]]
# Output: [[7,null],[13,0],[11,4],[10,2],[1,0]]
# ```
#
# **Concepts:** Hashing, In-place modification

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q9. Flatten a Multilevel Doubly Linked List
#
# **Difficulty:** Medium
#
# **Problem:**
# You are given a doubly linked list, which contains nodes that also have a `child` pointer that may point to another doubly linked list. Flatten the list so all nodes appear in a single-level doubly linked list.
#
# **Example:**
# ```
# Input:  head = [1, 2, 3, 4, 5, 6, null, null, null, 7, 8, 9, 10, ...]
# Output: [1, 2, 3, 7, 8, 9, 10, 4, 5, 6]
# ```
#
# **Concepts:** DFS, Stack, Recursion

# %%
# Write your solution here
