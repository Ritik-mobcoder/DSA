# %% [markdown]
# # Trees & Binary Trees
#
# > One of the most important areas for 3+ years experience.
#
# ---
#
# ## Key Concepts
#
# - DFS & BFS
# - Recursion
# - Tree traversal patterns (Inorder, Preorder, Postorder, Level Order)
# - BST properties
# - Height-balanced trees
#
# ---

# %% [markdown]
# ## Q1. Maximum Depth of Binary Tree
#
# **Difficulty:** Easy
#
# **Problem:**
# Given the root of a binary tree, return its maximum depth. The maximum depth is the number of nodes along the longest path from the root to the farthest leaf node.
#
# **Example:**
# ```
# Input:  root = [3, 9, 20, null, null, 15, 7]
# Output: 3
# ```
#
# **Concepts:** DFS, Recursion, BFS

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q2. Invert Binary Tree
#
# **Difficulty:** Easy
#
# **Problem:**
# Given the root of a binary tree, invert the tree (mirror it) and return its root.
#
# **Example:**
# ```
# Input:  root = [4, 2, 7, 1, 3, 6, 9]
# Output: [4, 7, 2, 9, 6, 3, 1]
# ```
#
# **Concepts:** DFS, Recursion, BFS

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q3. Diameter of Binary Tree
#
# **Difficulty:** Easy
#
# **Problem:**
# Given the root of a binary tree, return the length of the diameter of the tree. The diameter is the length of the longest path between any two nodes (may or may not pass through the root).
#
# **Example:**
# ```
# Input:  root = [1, 2, 3, 4, 5]
# Output: 3  (path: [4,2,1,3] or [5,2,1,3])
# ```
#
# **Concepts:** DFS, Recursion, Post-order traversal

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q4. Binary Tree Level Order Traversal
#
# **Difficulty:** Medium
#
# **Problem:**
# Given the root of a binary tree, return the level order traversal of its nodes' values (i.e., from left to right, level by level).
#
# **Example:**
# ```
# Input:  root = [3, 9, 20, null, null, 15, 7]
# Output: [[3], [9, 20], [15, 7]]
# ```
#
# **Concepts:** BFS, Queue

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q5. Lowest Common Ancestor (LCA)
#
# **Difficulty:** Medium
#
# **Problem:**
# Given a binary tree, find the lowest common ancestor (LCA) of two given nodes `p` and `q`.
#
# **Example:**
# ```
# Input:  root = [3,5,1,6,2,0,8,null,null,7,4], p = 5, q = 1
# Output: 3
# ```
#
# **Concepts:** DFS, Recursion, Tree traversal

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q6. Validate Binary Search Tree
#
# **Difficulty:** Medium
#
# **Problem:**
# Given the root of a binary tree, determine if it is a valid binary search tree (BST).
#
# **Example:**
# ```
# Input:  root = [2, 1, 3]
# Output: true
#
# Input:  root = [5, 1, 4, null, null, 3, 6]
# Output: false
# ```
#
# **Concepts:** DFS, BST properties, Inorder traversal

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q7. Kth Smallest Element in BST
#
# **Difficulty:** Medium
#
# **Problem:**
# Given the root of a binary search tree, and an integer `k`, return the `k`th smallest value (1-indexed) of all the values in the tree.
#
# **Example:**
# ```
# Input:  root = [3, 1, 4, null, 2], k = 1
# Output: 1
# ```
#
# **Concepts:** Inorder traversal, BST properties

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q8. Serialize and Deserialize Binary Tree
#
# **Difficulty:** Hard
#
# **Problem:**
# Design an algorithm to serialize and deserialize a binary tree. Serialization converts the tree to a string; deserialization reconstructs it from the string.
#
# **Example:**
# ```
# Input:  root = [1, 2, 3, null, null, 4, 5]
# Serialized: "1,2,3,null,null,4,5"
# Deserialized: [1, 2, 3, null, null, 4, 5]
# ```
#
# **Concepts:** BFS, DFS, Tree traversal

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q9. Path Sum
#
# **Difficulty:** Easy
#
# **Problem:**
# Given the root of a binary tree and an integer `targetSum`, return `true` if the tree has a root-to-leaf path such that adding up all the values along the path equals `targetSum`.
#
# **Example:**
# ```
# Input:  root = [5,4,8,11,null,13,4,7,2,null,null,null,1], targetSum = 22
# Output: true
# ```
#
# **Concepts:** DFS, Recursion

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q10. Right Side View of Binary Tree
#
# **Difficulty:** Medium
#
# **Problem:**
# Given the root of a binary tree, imagine yourself standing on the right side of it. Return the values of the nodes you can see ordered from top to bottom.
#
# **Example:**
# ```
# Input:  root = [1, 2, 3, null, 5, null, 4]
# Output: [1, 3, 4]
# ```
#
# **Concepts:** BFS, Level Order Traversal

# %%
# Write your solution here
