# %%
def bestTimeBuySellStock(n):
    pass
      
# lst = [1,2,3,4,5]
prices = [7, 1, 5, 3, 6, 4]
target = 20
print(bestTimeBuySellStock(20))
# Out:
# None

# %%
# Write your solution here
def maxProfit(lst):
        min_price = lst[0]
        max_profit = 0

        for price in lst:
            if price < min_price:
                min_price = price

            profit = price - min_price

            if profit > max_profit:
                max_profit = profit

        return max_profit
