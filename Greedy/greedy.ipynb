# %% [markdown]
# # Greedy Algorithms
#
# > Interviewers test whether you can identify greedy choices.
#
# ---
#
# ## Key Concepts
#
# - Sorting
# - Interval scheduling
# - Local optimum → Global optimum reasoning
#
# ---

# %% [markdown]
# ## Q1. Jump Game
#
# **Difficulty:** Medium
#
# **Problem:**
# Given an integer array `nums` where each element represents the maximum jump length at that position, return `true` if you can reach the last index starting from index 0.
#
# **Example:**
# ```
# Input:  nums = [2, 3, 1, 1, 4]
# Output: true
#
# Input:  nums = [3, 2, 1, 0, 4]
# Output: false
# ```
#
# **Concepts:** Greedy, Max reach tracking

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q2. Gas Station
#
# **Difficulty:** Medium
#
# **Problem:**
# There are `n` gas stations in a circle. You are given `gas[i]` (gas at station i) and `cost[i]` (gas to travel to the next station). Return the starting station index if you can complete the circuit once, otherwise return `-1`.
#
# **Example:**
# ```
# Input:  gas = [1,2,3,4,5], cost = [3,4,5,1,2]
# Output: 3
# ```
#
# **Concepts:** Greedy, Circular traversal

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q3. Non-overlapping Intervals
#
# **Difficulty:** Medium
#
# **Problem:**
# Given an array of intervals, return the minimum number of intervals you need to remove to make the rest non-overlapping.
#
# **Example:**
# ```
# Input:  intervals = [[1,2],[2,3],[3,4],[1,3]]
# Output: 1  (remove [1,3])
# ```
#
# **Concepts:** Greedy, Sorting, Interval scheduling

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q4. Meeting Rooms II
#
# **Difficulty:** Medium
#
# **Problem:**
# Given an array of meeting time intervals `[start, end]`, return the minimum number of conference rooms required.
#
# **Example:**
# ```
# Input:  intervals = [[0,30],[5,10],[15,20]]
# Output: 2
# ```
#
# **Concepts:** Greedy, Sorting, Min Heap

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q5. Minimum Number of Arrows to Burst Balloons
#
# **Difficulty:** Medium
#
# **Problem:**
# Balloons are represented as `[xstart, xend]` on a horizontal axis. An arrow shot at x bursts all balloons where `xstart <= x <= xend`. Return the minimum number of arrows needed to burst all balloons.
#
# **Example:**
# ```
# Input:  points = [[10,16],[2,8],[1,6],[7,12]]
# Output: 2
# ```
#
# **Concepts:** Greedy, Sorting, Interval scheduling

# %%
# Write your solution here
