# %% [markdown]
# # Stacks & Queues
#
# > Very common in backend and system design interviews.
#
# ---
#
# ## Key Concepts
#
# - Monotonic Stack
# - Deque
# - Stack-based parsing
#
# ---

# %% [markdown]
# ## Q1. Valid Parentheses
#
# **Difficulty:** Easy
#
# **Problem:**
# Given a string `s` containing just the characters `(`, `)`, `{`, `}`, `[` and `]`, determine if the input string is valid.
#
# **Example:**
# ```
# Input:  s = "()[]{}"
# Output: true
#
# Input:  s = "(]"
# Output: false
# ```
#
# **Concepts:** Stack, Stack-based parsing

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q2. Min Stack
#
# **Difficulty:** Medium
#
# **Problem:**
# Design a stack that supports push, pop, top, and retrieving the minimum element in constant time.
#
# **Example:**
# ```
# MinStack minStack = new MinStack();
# minStack.push(-2);
# minStack.push(0);
# minStack.push(-3);
# minStack.getMin(); // returns -3
# minStack.pop();
# minStack.top();    // returns 0
# minStack.getMin(); // returns -2
# ```
#
# **Concepts:** Stack, Auxiliary Stack

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q3. Evaluate Reverse Polish Notation
#
# **Difficulty:** Medium
#
# **Problem:**
# Evaluate the value of an arithmetic expression in Reverse Polish Notation. Valid operators are `+`, `-`, `*`, and `/`.
#
# **Example:**
# ```
# Input:  tokens = ["2","1","+","3","*"]
# Output: 9   ((2 + 1) * 3 = 9)
# ```
#
# **Concepts:** Stack, Stack-based parsing

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q4. Daily Temperatures
#
# **Difficulty:** Medium
#
# **Problem:**
# Given an array of integers `temperatures`, return an array `answer` such that `answer[i]` is the number of days you have to wait after the `i`th day to get a warmer temperature.
#
# **Example:**
# ```
# Input:  temperatures = [73,74,75,71,69,72,76,73]
# Output: [1, 1, 4, 2, 1, 1, 0, 0]
# ```
#
# **Concepts:** Monotonic Stack

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q5. Largest Rectangle in Histogram
#
# **Difficulty:** Hard
#
# **Problem:**
# Given an array of integers `heights` representing the histogram's bar height where the width of each bar is 1, return the area of the largest rectangle in the histogram.
#
# **Example:**
# ```
# Input:  heights = [2, 1, 5, 6, 2, 3]
# Output: 10
# ```
#
# **Concepts:** Monotonic Stack

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q6. Implement Queue using Stacks
#
# **Difficulty:** Easy
#
# **Problem:**
# Implement a first-in first-out (FIFO) queue using only two stacks. The queue should support `push`, `pop`, `peek`, and `empty` operations.
#
# **Example:**
# ```
# MyQueue queue = new MyQueue();
# queue.push(1);
# queue.push(2);
# queue.peek();  // returns 1
# queue.pop();   // returns 1
# queue.empty(); // returns false
# ```
#
# **Concepts:** Stack, Queue, Amortized complexity

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q7. Sliding Window Maximum
#
# **Difficulty:** Hard
#
# **Problem:**
# Given an array of integers `nums` and a sliding window of size `k`, return the max of each window as it moves from left to right.
#
# **Example:**
# ```
# Input:  nums = [1,3,-1,-3,5,3,6,7], k = 3
# Output: [3, 3, 5, 5, 6, 7]
# ```
#
# **Concepts:** Monotonic Deque, Sliding Window

# %%
# Write your solution here

# %% [markdown]
# ---
# ## Q8. Next Greater Element
#
# **Difficulty:** Easy
#
# **Problem:**
# Given two arrays `nums1` and `nums2`, for each element in `nums1`, find the next greater element in `nums2`. If no greater element exists, return `-1`.
#
# **Example:**
# ```
# Input:  nums1 = [4,1,2], nums2 = [1,3,4,2]
# Output: [-1, 3, -1]
# ```
#
# **Concepts:** Monotonic Stack, Hashing

# %%
# Write your solution here
